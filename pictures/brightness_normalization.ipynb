# %%
"""
Background Brightness Normalization Script - Updated Version
Uses TOP HALF of background only to avoid shadow influence
"""

import cv2
import numpy as np
from pathlib import Path
import re

def analyze_background_brightness(image_path, use_top_half=True):
    """
    Analyze average brightness of background (gray vinyl) - used as reference only
    
    Parameters:
    -----------
    image_path : str or Path
        Path to image
    use_top_half : bool
        If True, only use top half of image to avoid shadows (default: True)
    
    Returns:
    --------
    tuple: (brightness, img, hsv, mask)
    """
    img = cv2.imread(str(image_path))
    if img is None:
        print(f"Warning: Unable to read image {image_path}.")
        return None, None, None, None
    
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    height, width = img.shape[:2]
    
    # Create mask for gray areas (low saturation, high brightness)
    lower_gray = np.array([0, 0, 80])  
    upper_gray = np.array([180, 80, 230]) 
    mask = cv2.inRange(hsv, lower_gray, upper_gray)
    
    # Use only top half to avoid shadows at the bottom
    if use_top_half:
        mask[height//2:, :] = 0  # Zero out bottom half
    
    # Calculate average V (brightness) value of background
    v_channel = hsv[:,:,2]
    background_pixels = v_channel[mask > 0]
    
    if len(background_pixels) == 0:
        print(f"Warning: No background found in {image_path}.")
        return None, img, hsv, mask
    
    background_brightness = np.mean(background_pixels)
    
    return background_brightness, img, hsv, mask

def normalize_entire_image(image_path, target_brightness, output_path, use_top_half=True, verbose=True):
    """Adjust ENTIRE image brightness based on background reference"""
    current_brightness, img, hsv, mask = analyze_background_brightness(image_path, use_top_half)
    
    if current_brightness is None:
        return None
    
    if verbose:
        print(f"Processing: {Path(image_path).name}")
        print(f"  Background brightness (top half): {current_brightness:.1f}")
        print(f"  Target brightness: {target_brightness:.1f}")
        print(f"  Adjustment ratio: {target_brightness/current_brightness:.2f}x")
    
    # Calculate brightness adjustment ratio based on background
    brightness_ratio = target_brightness / current_brightness
    
    # Adjust V channel for THE ENTIRE IMAGE (not just background)
    v_channel = hsv[:,:,2].astype(float)
    
    # Apply adjustment to ALL pixels (plants + background)
    v_adjusted = np.clip(v_channel * brightness_ratio, 0, 255)
    
    # Merge back to HSV
    hsv[:,:,2] = v_adjusted.astype(np.uint8)
    
    # Convert to BGR
    result = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    
    # Save
    cv2.imwrite(str(output_path), result)
    
    if verbose:
        print(f"  ✓ Entire image adjusted and saved: {output_path}\n")
    
    return current_brightness

def should_process_file(filename, pattern_range, exclude_pattern='top'):
    """
    Check if file should be processed:
    1. Must end with -N.jpeg where N is in the specified range (1-16)
    2. Must NOT contain 'top' in the filename
    """
    # Check if contains exclude pattern
    if exclude_pattern.lower() in filename.lower():
        return False
    
    # Check if ends with -N.jpeg pattern
    for num in pattern_range:
        if filename.endswith(f"-{num}.jpeg") or filename.endswith(f"-{num}.JPEG"):
            return True
    
    return False

def process_multiple_folders(base_path, folder_names, output_folder_name='normalized',
                             include_pattern_range=range(1, 17), exclude_pattern='top',
                             target_brightness=None, use_top_half=True,
                             file_extensions=['.jpg', '.jpeg', '.png']):
    """Process multiple folders and save to normalized/day1, normalized/day2, etc."""
    
    base_path = Path(base_path)
    output_base = base_path / output_folder_name
    
    # Create normalized folder
    output_base.mkdir(exist_ok=True)
    
    # Collect all image files from all folders
    all_image_files = []
    
    print("=" * 60)
    print("Collecting images from folders...")
    print("=" * 60)
    
    for folder_name in folder_names:
        folder_path = base_path / folder_name
        
        if not folder_path.exists():
            print(f"Warning: Folder '{folder_name}' not found. Skipping...")
            continue
        
        # Create corresponding output folder
        output_folder = output_base / folder_name
        output_folder.mkdir(exist_ok=True)
        
        # Find image files
        folder_images = []
        for ext in file_extensions:
            folder_images.extend(folder_path.glob(f'*{ext}'))
            folder_images.extend(folder_path.glob(f'*{ext.upper()}'))
        
        # Filter: must match -N.jpeg pattern AND not contain 'top'
        filtered_images = [img for img in folder_images 
                          if should_process_file(img.name, include_pattern_range, exclude_pattern)]
        
        # Count excluded by each criterion for reporting
        excluded_by_top = len([img for img in folder_images if exclude_pattern.lower() in img.name.lower()])
        excluded_by_pattern = len([img for img in folder_images 
                                  if not any(img.name.endswith(f"-{num}.jpeg") or 
                                           img.name.endswith(f"-{num}.JPEG") 
                                           for num in include_pattern_range)])
        
        print(f"\n{folder_name}:")
        print(f"  Total images: {len(folder_images)}")
        print(f"  Excluded (contains '{exclude_pattern}'): {excluded_by_top}")
        print(f"  Excluded (not matching -1 to -16.jpeg): {excluded_by_pattern}")
        print(f"  To process: {len(filtered_images)}")
        
        all_image_files.extend(filtered_images)
    
    if not all_image_files:
        print("\nError: No images found to process.")
        return
    
    print(f"\n{'=' * 60}")
    print(f"Total images to process: {len(all_image_files)}")
    print(f"Output folder: {output_base}")
    print(f"Method: Entire image adjustment based on background reference")
    print(f"Background region: Top half only (avoids shadows) ⭐")
    print("=" * 60)
    
    # Step 1: Analyze background brightness of all images
    print("\nStep 1: Background Brightness Analysis (Top Half Only)")
    print("-" * 60)
    
    brightness_values = {}
    for img_file in all_image_files:
        brightness, _, _, _ = analyze_background_brightness(img_file, use_top_half)
        if brightness is not None:
            brightness_values[img_file] = brightness
            print(f"{img_file.parent.name}/{img_file.name}: {brightness:.1f}")
    
    if not brightness_values:
        print("Error: No processable images found.")
        return
    
    # Set target brightness
    if target_brightness is None:
        target_brightness = max(brightness_values.values())
        print(f"\n✓ Target brightness (auto-selected - brightest background): {target_brightness:.1f}")
    else:
        print(f"\n✓ Target brightness (manually set): {target_brightness:.1f}")
    
    # Step 2: Adjust all images to target brightness
    print(f"\n{'=' * 60}")
    print("Step 2: Entire Image Brightness Adjustment")
    print("(Plants and background both adjusted)")
    print("=" * 60)
    
    success_count = 0
    for img_file in brightness_values.keys():
        # Get the folder name (day1, day2, etc.)
        folder_name = img_file.parent.name
        
        # Create output path: normalized/day1/filename.jpg
        output_folder = output_base / folder_name
        output_file = output_folder / img_file.name
        
        result = normalize_entire_image(img_file, target_brightness, output_file, use_top_half)
        if result is not None:
            success_count += 1
    
    print("=" * 60)
    print(f"✓ Complete! {success_count} images processed")
    print(f"Results saved in: {output_base}/")
    print(f"  Structure: normalized/day1/, normalized/day2/, ...")
    print(f"\nNow all images simulate the same lighting conditions!")
    print(f"You can accurately compare plant colors across images.")
    print("=" * 60)

# ========================================
# Change settings here
# ========================================

# Input base path (folder containing day1, day2, etc.)
cwd = "/Users/jiwoohan/Documents/git/604-project-3/pictures"
folders = ['day0', 'day1', 'day2', 'day3', 'day4', 'day5']

# Output folder name
OUTPUT_FOLDER = 'normalized'

# Include pattern: only process files ending with -1.jpeg to -16.jpeg
INCLUDE_PATTERN_RANGE = range(1, 17)  # 1 to 16

# Exclude pattern: skip files containing this word
EXCLUDE_PATTERN = 'top'

# Target brightness (None = auto-select brightest background)
TARGET_BRIGHTNESS = None

# Use top half of background only (recommended to avoid shadows)
USE_TOP_HALF = True

# File extensions to process
FILE_EXTENSIONS = ['.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG']

# ========================================
# Start processing
# ========================================

if __name__ == "__main__":
    process_multiple_folders(
        base_path=cwd,
        folder_names=folders,
        output_folder_name=OUTPUT_FOLDER,
        include_pattern_range=INCLUDE_PATTERN_RANGE,
        exclude_pattern=EXCLUDE_PATTERN,
        target_brightness=TARGET_BRIGHTNESS,
        use_top_half=USE_TOP_HALF,
        file_extensions=FILE_EXTENSIONS
    )
# Out:
# ============================================================
# Collecting images from folders...
# ============================================================
#
# day0:
#   Total images: 36
#   Excluded (contains 'top'): 0
#   Excluded (not matching -1 to -16.jpeg): 20
#   To process: 16
#
# day1:
#   Total images: 38
#   Excluded (contains 'top'): 16
#   Excluded (not matching -1 to -16.jpeg): 6
#   To process: 16
#
# day2:
#   Total images: 38
#   Excluded (contains 'top'): 16
#   Excluded (not matching -1 to -16.jpeg): 6
#   To process: 16
#
# day3:
#   Total images: 38
#   Excluded (contains 'top'): 16
#   Excluded (not matching -1 to -16.jpeg): 6
#   To process: 16
#
# day4:
#   Total images: 38
#   Excluded (contains 'top'): 16
#   Excluded (not matching -1 to -16.jpeg): 6
#   To process: 16
#
# day5:
#   Total images: 38
#   Excluded (contains 'top'): 16
#   Excluded (not matching -1 to -16.jpeg): 6
#   To process: 16
#
# ============================================================
# Total images to process: 96
# Output folder: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized
# Method: Entire image adjustment based on background reference
# Background region: Top half only (avoids shadows) ⭐
# ============================================================
#
# Step 1: Background Brightness Analysis (Top Half Only)
# ------------------------------------------------------------
# day0/room-water-7.jpeg: 146.6
# day0/low-water-8.jpeg: 158.0
# day0/low-waterless-12.jpeg: 181.8
# day0/low-waterless-1.jpeg: 109.0
# day0/room-waterless-4.jpeg: 123.4
# day0/low-waterless-6.jpeg: 137.6
# day0/room-water-13.jpeg: 177.3
# day0/low-water-2.jpeg: 119.5
# day0/room-waterless-11.jpeg: 178.4
# day0/low-water-16.jpeg: 164.1
# day0/room-water-3.jpeg: 120.1
# day0/low-waterless-9.jpeg: 165.0
# day0/room-waterless-14.jpeg: 173.5
# day0/low-water-10.jpeg: 174.1
# day0/room-water-5.jpeg: 136.8
# day0/room-waterless-15.jpeg: 167.5
# day1/room-water-7.jpeg: 158.7
# day1/low-water-8.jpeg: 183.1
# day1/low-waterless-12.jpeg: 170.9
# day1/low-waterless-1.jpeg: 169.5
# day1/room-waterless-4.jpeg: 165.4
# day1/low-waterless-6.jpeg: 142.7
# day1/room-water-13.jpeg: 185.5
# day1/low-water-2.jpeg: 177.4
# day1/room-waterless-11.jpeg: 147.9
# day1/low-water-16.jpeg: 166.3
# day1/room-water-3.jpeg: 159.3
# day1/low-waterless-9.jpeg: 148.4
# day1/room-waterless-14.jpeg: 151.9
# day1/low-water-10.jpeg: 167.5
# day1/room-water-5.jpeg: 164.0
# day1/room-waterless-15.jpeg: 180.2
# day2/room-water-7.jpeg: 160.4
# day2/low-water-8.jpeg: 148.4
# day2/low-waterless-12.jpeg: 168.2
# day2/low-waterless-1.jpeg: 180.3
# day2/room-waterless-4.jpeg: 180.5
# day2/low-waterless-6.jpeg: 154.4
# day2/room-water-13.jpeg: 177.6
# day2/low-water-2.jpeg: 164.8
# day2/room-waterless-11.jpeg: 158.6
# day2/low-water-16.jpeg: 174.9
# day2/room-water-3.jpeg: 183.1
# day2/low-waterless-9.jpeg: 153.2
# day2/room-waterless-14.jpeg: 158.0
# day2/low-water-10.jpeg: 152.2
# day2/room-water-5.jpeg: 174.8
# day2/room-waterless-15.jpeg: 173.0
# day3/room-water-7.jpeg: 166.7
# day3/low-water-8.jpeg: 159.2
# day3/low-waterless-12.jpeg: 176.0
# day3/low-waterless-1.jpeg: 180.6
# day3/room-waterless-4.jpeg: 180.7
# day3/low-waterless-6.jpeg: 159.3
# day3/room-water-13.jpeg: 177.0
# day3/low-water-2.jpeg: 167.4
# day3/room-waterless-11.jpeg: 174.4
# day3/low-water-16.jpeg: 166.9
# day3/room-water-3.jpeg: 173.5
# day3/low-waterless-9.jpeg: 163.1
# day3/room-waterless-14.jpeg: 161.9
# day3/low-water-10.jpeg: 166.6
# day3/room-water-5.jpeg: 158.3
# day3/room-waterless-15.jpeg: 178.2
# day4/room-water-7.jpeg: 172.1
# day4/low-water-8.jpeg: 165.2
# day4/low-waterless-12.jpeg: 183.4
# day4/low-waterless-1.jpeg: 187.7
# day4/room-waterless-4.jpeg: 190.9
# day4/low-waterless-6.jpeg: 183.2
# day4/room-water-13.jpeg: 178.7
# day4/low-water-2.jpeg: 180.5
# day4/room-waterless-11.jpeg: 190.6
# day4/low-water-16.jpeg: 176.2
# day4/room-water-3.jpeg: 180.9
# day4/low-waterless-9.jpeg: 185.8
# day4/room-waterless-14.jpeg: 166.5
# day4/low-water-10.jpeg: 180.3
# day4/room-water-5.jpeg: 182.1
# day4/room-waterless-15.jpeg: 174.7
# day5/room-water-7.jpeg: 184.8
# day5/low-water-8.jpeg: 168.0
# day5/low-waterless-12.jpeg: 188.3
# day5/low-waterless-1.jpeg: 188.3
# day5/room-waterless-4.jpeg: 184.4
# day5/low-waterless-6.jpeg: 177.2
# day5/room-water-13.jpeg: 181.1
# day5/low-water-2.jpeg: 181.9
# day5/room-waterless-11.jpeg: 186.0
# day5/low-water-16.jpeg: 182.1
# day5/room-water-3.jpeg: 182.7
# day5/low-waterless-9.jpeg: 185.4
# day5/room-waterless-14.jpeg: 177.6
# day5/low-water-10.jpeg: 182.2
# day5/room-water-5.jpeg: 181.4
# day5/room-waterless-15.jpeg: 183.9
#
# ✓ Target brightness (auto-selected - brightest background): 190.9
#
# ============================================================
# Step 2: Entire Image Brightness Adjustment
# (Plants and background both adjusted)
# ============================================================
# Processing: room-water-7.jpeg
#   Background brightness (top half): 146.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.30x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 158.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.21x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 181.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 109.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.75x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 123.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.55x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 137.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.39x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 177.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 119.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.60x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 178.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.07x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 164.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.16x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 120.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.59x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 165.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.16x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 173.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.10x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 174.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.10x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 136.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.39x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 167.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day0/room-waterless-15.jpeg
#
# Processing: room-water-7.jpeg
#   Background brightness (top half): 158.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.20x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 183.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 170.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.12x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 169.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.13x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 165.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.15x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 142.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.34x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 185.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 177.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 147.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.29x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 166.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.15x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 159.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.20x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 148.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.29x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 151.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.26x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 167.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 164.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.16x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 180.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day1/room-waterless-15.jpeg
#
# Processing: room-water-7.jpeg
#   Background brightness (top half): 160.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.19x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 148.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.29x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 168.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 180.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 180.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 154.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.24x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 177.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.07x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 164.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.16x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 158.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.20x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 174.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.09x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 183.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 153.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.25x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 158.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.21x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 152.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.25x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 174.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.09x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 173.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.10x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day2/room-waterless-15.jpeg
#
# Processing: room-water-7.jpeg
#   Background brightness (top half): 166.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 159.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.20x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 176.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 180.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 180.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 159.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.20x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 177.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 167.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 174.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.09x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 166.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 173.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.10x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 163.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.17x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 161.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.18x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 166.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.15x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 158.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.21x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 178.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.07x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day3/room-waterless-15.jpeg
#
# Processing: room-water-7.jpeg
#   Background brightness (top half): 172.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.11x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 165.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.16x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 183.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 187.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.02x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 190.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.00x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 183.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 178.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.07x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 180.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 190.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.00x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 176.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 180.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 185.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 166.5
#   Target brightness: 190.9
#   Adjustment ratio: 1.15x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 180.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.06x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 182.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 174.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.09x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day4/room-waterless-15.jpeg
#
# Processing: room-water-7.jpeg
#   Background brightness (top half): 184.8
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-water-7.jpeg
#
# Processing: low-water-8.jpeg
#   Background brightness (top half): 168.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.14x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-water-8.jpeg
#
# Processing: low-waterless-12.jpeg
#   Background brightness (top half): 188.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.01x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-waterless-12.jpeg
#
# Processing: low-waterless-1.jpeg
#   Background brightness (top half): 188.3
#   Target brightness: 190.9
#   Adjustment ratio: 1.01x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-waterless-1.jpeg
#
# Processing: room-waterless-4.jpeg
#   Background brightness (top half): 184.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-waterless-4.jpeg
#
# Processing: low-waterless-6.jpeg
#   Background brightness (top half): 177.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.08x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-waterless-6.jpeg
#
# Processing: room-water-13.jpeg
#   Background brightness (top half): 181.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-water-13.jpeg
#
# Processing: low-water-2.jpeg
#   Background brightness (top half): 181.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-water-2.jpeg
#
# Processing: room-waterless-11.jpeg
#   Background brightness (top half): 186.0
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-waterless-11.jpeg
#
# Processing: low-water-16.jpeg
#   Background brightness (top half): 182.1
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-water-16.jpeg
#
# Processing: room-water-3.jpeg
#   Background brightness (top half): 182.7
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-water-3.jpeg
#
# Processing: low-waterless-9.jpeg
#   Background brightness (top half): 185.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.03x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-waterless-9.jpeg
#
# Processing: room-waterless-14.jpeg
#   Background brightness (top half): 177.6
#   Target brightness: 190.9
#   Adjustment ratio: 1.07x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-waterless-14.jpeg
#
# Processing: low-water-10.jpeg
#   Background brightness (top half): 182.2
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/low-water-10.jpeg
#
# Processing: room-water-5.jpeg
#   Background brightness (top half): 181.4
#   Target brightness: 190.9
#   Adjustment ratio: 1.05x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-water-5.jpeg
#
# Processing: room-waterless-15.jpeg
#   Background brightness (top half): 183.9
#   Target brightness: 190.9
#   Adjustment ratio: 1.04x
#   ✓ Entire image adjusted and saved: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/day5/room-waterless-15.jpeg
#
# ============================================================
# ✓ Complete! 96 images processed
# Results saved in: /Users/jiwoohan/Documents/git/604-project-3/pictures/normalized/
#   Structure: normalized/day1/, normalized/day2/, ...
#
# Now all images simulate the same lighting conditions!
# You can accurately compare plant colors across images.
# ============================================================

# %%
"""
Flower Color Analysis to CSV - SIMPLIFIED VERSION
Focus on detecting yellow flowers while excluding green stems
Based on the methodology: Yellow detection + Green exclusion
Saves 9 CSV files: RGB (R, G, B), HSV (H, S, V), LAB (L, a, b)
"""

import cv2
import numpy as np
from pathlib import Path
import csv

def detect_flowers_simple(image_path):
    """
    Simple flower detection focusing on yellow flowers
    Excludes only green stems
    """
    img = cv2.imread(str(image_path))
    if img is None:
        return None, None
    
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    # Step 1: Detect yellow flowers (broader range)
    # Hue: 15-35 (yellow to orange)
    # Saturation: 30+ (has color, not gray)
    # Value: 50+ (not too dark)
    lower_flower = np.array([15, 30, 50])
    upper_flower = np.array([35, 255, 255])
    mask_flower = cv2.inRange(hsv, lower_flower, upper_flower)
    
    # Step 2: Exclude green stems
    # Hue: 35-85 (green range)
    # Saturation: 40+ (definitely green, not brown/gray)
    # Value: 20+ (not completely black)
    lower_green = np.array([35, 40, 20])
    upper_green = np.array([85, 255, 255])
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    
    # Apply exclusion
    mask = cv2.bitwise_and(mask_flower, cv2.bitwise_not(mask_green))
    
    # Light cleanup with morphological operations
    kernel = np.ones((3, 3), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    
    return img, mask

def analyze_flower_color(image_path, mask=None):
    """Analyze flower color in RGB, HSV, and LAB color spaces"""
    if mask is None:
        img, mask = detect_flowers_simple(image_path)
        if img is None:
            return None
    else:
        img = cv2.imread(str(image_path))
    
    # Convert to different color spaces
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    
    # Extract flower pixels
    flower_pixels_rgb = img_rgb[mask > 0]
    flower_pixels_hsv = hsv[mask > 0]
    flower_pixels_lab = lab[mask > 0]
    
    if len(flower_pixels_rgb) == 0:
        return None
    
    # Calculate means
    rgb_mean = np.mean(flower_pixels_rgb, axis=0)
    hsv_mean = np.mean(flower_pixels_hsv, axis=0)
    lab_mean = np.mean(flower_pixels_lab, axis=0)
    
    return {
        'RGB_mean_R': rgb_mean[0],
        'RGB_mean_G': rgb_mean[1],
        'RGB_mean_B': rgb_mean[2],
        'HSV_mean_H': hsv_mean[0],
        'HSV_mean_S': hsv_mean[1],
        'HSV_mean_V': hsv_mean[2],
        'LAB_mean_L': lab_mean[0],
        'LAB_mean_a': lab_mean[1],
        'LAB_mean_b': lab_mean[2],
        'pixel_count': len(flower_pixels_rgb),
    }

def process_folders_to_csv(base_path, folder_names, output_folder, 
                           image_range=range(1, 17), exclude_pattern='top'):
    """
    Process multiple folders and create 9 CSV files
    
    Parameters:
    -----------
    base_path : str
        Base path containing day folders
    folder_names : list
        List of folder names (e.g., ['day0', 'day1', 'day2', ...])
    output_folder : str
        Where to save CSV files
    image_range : range
        Range of image numbers to process (default: 1-16)
    exclude_pattern : str
        Pattern to exclude from filenames (default: 'top')
    """
    
    base_path = Path(base_path)
    output_folder = Path(output_folder)
    output_folder.mkdir(parents=True, exist_ok=True)
    
    # Initialize data structure
    data = {
        'RGB_R': {},
        'RGB_G': {},
        'RGB_B': {},
        'HSV_H': {},
        'HSV_S': {},
        'HSV_V': {},
        'LAB_L': {},
        'LAB_a': {},
        'LAB_b': {}
    }
    
    for img_num in image_range:
        for metric in data.keys():
            data[metric][img_num] = {}
    
    print("=" * 70)
    print("SIMPLIFIED Flower Color Analysis")
    print("=" * 70)
    print("Detection method:")
    print("  ✓ Yellow flower detection (H: 15-35, S: 30+, V: 50+)")
    print("  ✓ Green stem exclusion (H: 35-85, S: 40+, V: 20+)")
    print("  ✓ Minimal post-processing")
    print("=" * 70)
    
    # Process each folder
    for folder_name in folder_names:
        folder_path = base_path / folder_name
        
        if not folder_path.exists():
            print(f"\nWarning: {folder_name} not found, skipping...")
            continue
        
        print(f"\nProcessing {folder_name}...")
        
        # Process each image number
        for img_num in image_range:
            # Find files matching pattern
            matching_files = []
            for ext in ['.jpeg', '.jpg', '.png', '.JPEG', '.JPG', '.PNG']:
                matching_files.extend(folder_path.glob(f"*-{img_num}{ext}"))
            
            # Filter out files with exclude pattern
            if exclude_pattern:
                matching_files = [f for f in matching_files 
                                if exclude_pattern.lower() not in f.name.lower()]
            
            if not matching_files:
                print(f"  Image {img_num}: Not found")
                continue
            
            # Use first matching file
            img_path = matching_files[0]
            
            # Analyze color
            stats = analyze_flower_color(img_path)
            
            if stats:
                # Store data
                data['RGB_R'][img_num][folder_name] = stats['RGB_mean_R']
                data['RGB_G'][img_num][folder_name] = stats['RGB_mean_G']
                data['RGB_B'][img_num][folder_name] = stats['RGB_mean_B']
                data['HSV_H'][img_num][folder_name] = stats['HSV_mean_H']
                data['HSV_S'][img_num][folder_name] = stats['HSV_mean_S']
                data['HSV_V'][img_num][folder_name] = stats['HSV_mean_V']
                data['LAB_L'][img_num][folder_name] = stats['LAB_mean_L']
                data['LAB_a'][img_num][folder_name] = stats['LAB_mean_a']
                data['LAB_b'][img_num][folder_name] = stats['LAB_mean_b']
                
                print(f"  Image {img_num}: ✓")
            else:
                print(f"  Image {img_num}: No flowers detected")
    
    # Save to CSV files
    print("\n" + "=" * 70)
    print("Saving to CSV files...")
    print("=" * 70)
    
    for metric_name, metric_data in data.items():
        csv_path = output_folder / f"{metric_name}.csv"
        
        with open(csv_path, 'w', newline='') as f:
            writer = csv.writer(f)
            
            # Header row
            header = ['image_number'] + folder_names
            writer.writerow(header)
            
            # Data rows
            for img_num in sorted(metric_data.keys()):
                row = [img_num]
                for folder in folder_names:
                    value = metric_data[img_num].get(folder, '')
                    if value != '':
                        if metric_name == 'pixel_count':
                            value = int(value)
                        else:
                            value = f"{value:.2f}"
                    row.append(value)
                writer.writerow(row)
        
        print(f"✓ {csv_path.name}")
    
    print("=" * 70)
    print(f"✓ Complete! {len(data)} CSV files saved to {output_folder}")
    print("\nFiles created:")
    print("  - RGB_R.csv, RGB_G.csv, RGB_B.csv")
    print("  - HSV_H.csv, HSV_S.csv, HSV_V.csv")
    print("  - LAB_L.csv, LAB_a.csv, LAB_b.csv")
    print("=" * 70)

# ========================================
# Configuration
# ========================================

# Base path (folder containing day0, day1, etc.)
BASE_PATH = "/Users/jiwoohan/Documents/git/604-project-3/pictures/normalized"

# Folder names (days)
FOLDERS = ['day0', 'day1', 'day2', 'day3', 'day4', 'day5']

# Output folder for CSV files
OUTPUT_FOLDER = "/Users/jiwoohan/Documents/git/604-project-3/pictures/flower_color_data"

# Image number range (1-16)
IMAGE_RANGE = range(1, 17)

# Pattern to exclude (set to None to include all files)
EXCLUDE_PATTERN = 'top'

# ========================================
# Run
# ========================================

if __name__ == "__main__":
    process_folders_to_csv(
        base_path=BASE_PATH,
        folder_names=FOLDERS,
        output_folder=OUTPUT_FOLDER,
        image_range=IMAGE_RANGE,
        exclude_pattern=EXCLUDE_PATTERN
    )
# Out:
# ======================================================================
# SIMPLIFIED Flower Color Analysis
# ======================================================================
# Detection method:
#   ✓ Yellow flower detection (H: 15-35, S: 30+, V: 50+)
#   ✓ Green stem exclusion (H: 35-85, S: 40+, V: 20+)
#   ✓ Minimal post-processing
# ======================================================================
#
# Processing day0...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# Processing day1...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# Processing day2...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# Processing day3...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# Processing day4...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# Processing day5...
#   Image 1: ✓
#   Image 2: ✓
#   Image 3: ✓
#   Image 4: ✓
#   Image 5: ✓
#   Image 6: ✓
#   Image 7: ✓
#   Image 8: ✓
#   Image 9: ✓
#   Image 10: ✓
#   Image 11: ✓
#   Image 12: ✓
#   Image 13: ✓
#   Image 14: ✓
#   Image 15: ✓
#   Image 16: ✓
#
# ======================================================================
# Saving to CSV files...
# ======================================================================
# ✓ RGB_R.csv
# ✓ RGB_G.csv
# ✓ RGB_B.csv
# ✓ HSV_H.csv
# ✓ HSV_S.csv
# ✓ HSV_V.csv
# ✓ LAB_L.csv
# ✓ LAB_a.csv
# ✓ LAB_b.csv
# ======================================================================
# ✓ Complete! 9 CSV files saved to /Users/jiwoohan/Documents/git/604-project-3/pictures/flower_color_data
#
# Files created:
#   - RGB_R.csv, RGB_G.csv, RGB_B.csv
#   - HSV_H.csv, HSV_S.csv, HSV_V.csv
#   - LAB_L.csv, LAB_a.csv, LAB_b.csv
# ======================================================================
